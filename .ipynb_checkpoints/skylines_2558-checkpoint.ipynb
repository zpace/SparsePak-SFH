# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.table as table
import matplotlib as mpl
import matplotlib.image as mpimg
import os
import SPaCT
from astroML.datasets import fetch_sdss_spectrum
import warnings
from matplotlib.colors import LogNorm

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['figure.figsize'] = 8, 6

# %%
plt.figure(figsize = (12, 12), dpi = 250)
im = fits.open('../NGC2558/NGC2558.disp_cor.fits')[0].data
allfibers = plt.imshow((im.T/np.average(im, axis = 1).T).T, origin = 'lower', aspect = 1700/72, cmap = 'gnuplot2', norm = LogNorm(), interpolation = 'nearest')
plt.colorbar(allfibers, shrink = 0.8)
skyfibers = [80, 2, 22, 70, 54, 37]
for fiber in skyfibers:
    plt.axhline(float(fiber), linestyle = '--', c = 'b')
plt.show()

# %%
fiber = 52
#plt.plot(im[fiber, :np.min(np.where(im[fiber] 0.))])
#np.where(im[fiber] == )
print im[fiber, -18:-1]
print np.min(im[fiber, -18:-1])
plt.semilogy(im[fiber])

for x in range(im[fiber]):
    if im[fiber, x] <= 0.:
        plt.axvline(x, c = 'r')
# Out:
# ERROR:astropy:TypeError: only length-1 arrays can be converted to Python scalars
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-a60075a38f5e> in <module>()
#       6 plt.semilogy(im[fiber])
#       7
# ----> 8 for x in range(im[fiber]):
#       9     if im[fiber, x] <= 0.:
#      10         plt.axvline(x, c = 'r')
#
# TypeError: only length-1 arrays can be converted to Python scalars
# [  2.85912866e+03   2.81529004e+03   2.73001367e+03   1.71722754e+03
#    6.40397522e+02  -1.09184444e+00   3.77751589e-01   3.86890978e-01
#   -5.70029676e-01   7.99182594e-01   1.27464032e+00   8.55130136e-01
#   -6.97983384e-01  -1.25512600e+00  -7.43844807e-02   9.82362449e-01
#    2.07468891e+00]
# -1.25513
# ERROR: TypeError: only length-1 arrays can be converted to Python scalars [IPython.core.interactiveshell]
