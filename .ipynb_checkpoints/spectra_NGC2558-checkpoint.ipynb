# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.table as table
import matplotlib as mpl
import matplotlib.image as mpimg
import os
import SPaCT
from astroML.datasets import fetch_sdss_spectrum
import warnings
from scipy.stats import signaltonoise
import colorpy.ciexyz as ciexyz
import colorpy.colormodels as cmodels
from astropy.io import ascii

warnings.filterwarnings("ignore", message="using a non-integer number instead of an integer will result in an error in the future")

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['figure.figsize'] = 16, 12

sys.path.insert(0, '../../ppxf')

objname = 'NGC2558'
z = 0.0166076 #"accepted" SDSS redshift

im=fits.open(objname + '.msobj.fits')
#plt.imshow(im[0].data, cmap='bone')

NAXIS1 = im[0].header['NAXIS1']; print NAXIS1
CRVAL1 = im[0].header['CRVAL1']; print CRVAL1
CDELT1 = im[0].header['CDELT1']; print CDELT1
wavelength = np.arange(CRVAL1, CRVAL1 + CDELT1 * (NAXIS1 + 1), CDELT1 )
fibers = table.Table.read('../../fibers.txt', format='ascii')

#get the target coordinates and print them

f = open(objname + '.list')
targ_raw_im_name = f.readline()
n_img = len(f.readlines()) + 1
h = fits.open(targ_raw_im_name)[0].header

#print h['TARGRA']
#print h['TARGDEC']

ralist = [float(i) for i in str(h['TARGRA']).split(':')]
declist = [float(i) for i in str(h['TARGDEC']).split(':')]
for i in range(0, 3):
    ralist[i] = ralist[i] * [360./24., 360./24./60., 360./24./60./60.][i]
    declist[i] = declist[i] * [1., 1./60., 1./60./60.][i]

print 'coords:', sum(ralist), sum(declist)
# Out:
# 1934
# 3907
# 1.4
# coords: 124.802916667 20.5108555556

# %%
def circles(x, y, s, c='b', ax=None, vmin=None, vmax=None, **kwargs):
    """
    Make a scatter of circles plot of x vs y, where x and y are sequence 
    like objects of the same lengths. The size of circles are in data scale.

    Parameters
    ----------
    x,y : scalar or array_like, shape (n, )
        Input data
    s : scalar or array_like, shape (n, ) 
        Radius of circle in data scale (ie. in data unit)
    c : color or sequence of color, optional, default : 'b'
        `c` can be a single color format string, or a sequence of color
        specifications of length `N`, or a sequence of `N` numbers to be
        mapped to colors using the `cmap` and `norm` specified via kwargs.
        Note that `c` should not be a single numeric RGB or
        RGBA sequence because that is indistinguishable from an array of
        values to be colormapped.  `c` can be a 2-D array in which the
        rows are RGB or RGBA, however.
    ax : Axes object, optional, default: None
        Parent axes of the plot. It uses gca() if not specified.
    vmin, vmax : scalar, optional, default: None
        `vmin` and `vmax` are used in conjunction with `norm` to normalize
        luminance data.  If either are `None`, the min and max of the
        color array is used.  (Note if you pass a `norm` instance, your
        settings for `vmin` and `vmax` will be ignored.)

    Returns
    -------
    paths : `~matplotlib.collections.PathCollection`

    Other parameters
    ----------------
    kwargs : `~matplotlib.collections.Collection` properties
        eg. alpha, edgecolors, facecolors, linewidths, linestyles, norm, cmap

    Examples
    --------
    a = np.arange(11)
    circles(a, a, a*0.2, c=a, alpha=0.5, edgecolor='none')
    """
    from matplotlib.patches import Circle
    from matplotlib.collections import PatchCollection
    import pylab as plt
    #import matplotlib.colors as colors

    if ax is None:
        ax = plt.gca()    

    if isinstance(c,basestring):
        color = c     # ie. use colors.colorConverter.to_rgba_array(c)
    else:
        color = None  # use cmap, norm after collection is created
    kwargs.update(color=color)

    if isinstance(x, (int, long, float)):
        patches = [Circle((x, y), s),]
    elif isinstance(s, (int, long, float)):
        patches = [Circle((x_,y_), s) for x_,y_ in zip(x,y)]
    else:
        patches = [Circle((x_,y_), s_) for x_,y_,s_ in zip(x,y,s)]
    collection = PatchCollection(patches, **kwargs)

    if color is None:
        collection.set_array(np.asarray(c))
        if vmin is not None or vmax is not None:
            collection.set_clim(vmin, vmax)

    ax.add_collection(collection)
    return collection

def noise_detlim(signal_counts, response, RN, gain, t, npix = 1.):
    '''
    calculate noise associated with a number of fibers, assuming sky subtraction is done well
    
    (See MAB's Astro500 notes for more complete treatment)
    
    Arguments:
     - signal_counts: flux, converted to photon counts. 1-D numpy array, with nfibers rows of npix pixels
     - response: 1-D numpy array, npix long, giving system response
     - RN: read noise (in e-)
     - gain: adu/e-
     - npix (1): the number of pixels (only change this with very good reason!)
     
    Returns:
     - noise: a 1-D array (same dims as signal_counts) 
    '''
    
    import numpy as np
    return np.sqrt(signal_counts * response * t + (RN + gain/2.)**2. * npix)

def signal(signal_counts, response, t):
    import numpy as np
    return signal_counts * response * t

def SNR(S_obj, e, t, I_sky, RN, npix):
    s = S_obj * e * t
    n = np.sqrt(S_obj * e * t + I_sky * e * t * npix + RN**2. * npix)
    return s/n

def plusminus(s):
    if s == 'p':
        return 1.
    if s == 'm':
        return -1.
    else:
        print 'bad input: plusminus takes either \'p\' or \'m\'!'

# %% [markdown]
# # Fun with Fiber Layout

# %%
#test fiber map
fibersize=4.687

fig = plt.figure(figsize=(8,8))
for row in fibers:
    plt.scatter(row['ra'], row['dec'], s=300, c='y')
    plt.text(row['ra']-2, row['dec']-1.5, s=row['fiber'], color='k')
    
plt.xlabel(r'RA (arcsec)')
plt.ylabel(r'dec (arcsec)')
plt.title('SparsePak fiber spectrograph rows')

# %%
fig = plt.figure(figsize=(8,8), dpi=200)
for row in fibers:
    if row['sky']!=1:
        plt.scatter(row['ra'], row['dec'], s=750, c='y')
        plt.text(row['ra']-.85, row['dec']-.85, s=row['row'], color='k')
    
plt.xlabel(r'RA offset from center (arcsec)')
plt.ylabel(r'Dec offset from center (arcsec)')
plt.title('SparsePak fiber data rows')

# %%
#now put the fibers into radius bins
fibers = table.Table.read('../../fibers.txt', format='ascii')
radius = table.Column(name = 'r', data = np.sqrt( (np.asarray(fibers['ra']))**2. + (np.asarray(fibers['dec']))**2. ) )
#print 'radius:', len(radius)
#print 'fibers:', len(fibers)

if 'radius' not in fibers.colnames:
    fibers.add_column(radius)

fig = plt.figure(figsize=(6,6), dpi=200)
for row in fibers:
    if row['sky']!=1:
        plt.scatter(row['ra'], row['dec'], s=500, c='y')
        plt.text(row['ra']-.85, row['dec']-.85, s=row['fiber'], color='k')
        #print row['ra'], row['dec'], row['row']
        
circles(np.zeros(len(np.unique(radius))), np.zeros(len(np.unique(radius))), np.unique(radius)[::-1], c='w', edgecolor = 'k', alpha = 0.9, linestyle = '--', lw = 1, zorder = 0)

plt.xlabel(r'RA offset from center (arcsec)')
plt.ylabel(r'Dec offset from center (arcsec)')
plt.title('SparsePak fiber rows')

fibers.sort(['r'])
#fibers.pprint(max_lines=-1, max_width=-1)

# %%
#now figure out radius groups

fig = plt.figure(figsize=(16,16), dpi=200)

from sklearn.cluster import MeanShift, estimate_bandwidth

R = np.array(zip(fibers['r'][fibers['sky']!=1], np.zeros(len(fibers['r'][fibers['sky']!=1]))))
bandwidth = estimate_bandwidth(R, quantile=.08)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
ms.fit(R)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

#now match fibers to a radius group by iterating
group = -9999*np.ones(len(fibers['r'])).astype(int)
r_group_dict = {}

for k in range(n_clusters_):
    my_members = labels == k
    #print "cluster {0}: {1}".format(k, R[my_members, 0])
    plt.axhline(np.mean(R[my_members, 0]))
    #print k, my_members
    for i, fiber in enumerate(my_members):
        if fiber==True:
            group[i] = k
    r_group_dict[k] = np.mean(R[my_members, 0])
#print group
print r_group_dict

r_group = table.Column(name = 'r group', data = group)
if 'r group' not in fibers.colnames:
    fibers.add_column(r_group)

for i, row in enumerate(fibers):
    if row['sky']!=1:
        plt.scatter(i, row['r'])
        plt.annotate(str(row['fiber']) + '\n' + str(row['row']), (i, row['r']), xytext=(i, row['r']+4*(i%2)-2.), arrowprops=dict(arrowstyle='-|>'))
        #print row['ra'], row['dec'], row['row']
#plt.yscale('log')
#plt.ylim([-5., 60.])
plt.title('radial bins')
plt.annotate('fiber \n data', (8, 35), xytext = (10, 40), fontsize = 16, arrowprops=dict(arrowstyle='-|>'))

print fibers
#fibers now includes a radius-group designation for each fiber, so we can radially bin data. This method should actually be fairly extensible to other IFUs
#we also have a dictionary r_group_dict, which associates each group number with a mean radius
ascii.write(fibers, 'fiberdata.dat')
# Out:
# {0: 25.924020397058879, 1: 35.340783724952374, 2: 33.953369315093624, 3: 9.7995865171465244, 4: 5.6597283309216335, 5: 19.604903571224114, 6: 16.976698002306907, 7: 29.404489025232696, 8: 44.879911987435982, 9: 42.792160496988231, 10: 39.101112516142052, 11: 11.26, 12: 0.0}
# fiber   ra    dec   sky  row        r       r group
# ----- ------ ------ --- ----- ------------- -------
#    52    0.0    0.0   0    47           0.0      12
#    31    0.0  -5.63   0    27          5.63       4
#    47    0.0   5.63   0    42          5.63       4
#    26   4.93   2.81   0    22 5.67459249638       4
#    43  -4.93   2.81   0    38 5.67459249638       4
#    46   4.93  -2.81   0    41 5.67459249638       4
#    66  -4.93  -2.81   0    60 5.67459249638       4
#    25   4.93  -8.44   0    21 9.77437977572       3
#    41   4.93   8.44   0    36 9.77437977572       3
#    51  -4.93  -8.44   0    46 9.77437977572       3
#    62  -4.93   8.44   0    56 9.77437977572       3
#   ...    ...    ... ...   ...           ...     ...
#     6  29.56  33.77   0     4 44.8799119874       8
#    12  29.56 -33.77   0    10 44.8799119874       8
#    57 -29.56  33.77   0    51 44.8799119874       8
#    72 -29.56 -33.77   0    65 44.8799119874       8
#    16    0.0  61.92   1 -9999         61.92   -9999
#    80 -64.05   2.81   1 -9999  64.111610493   -9999
#     2 -29.56  61.92   1 -9999  68.613992742   -9999
#    22  29.56  61.92   1 -9999  68.613992742   -9999
#    70 -64.05 -30.96   1 -9999 71.1401721955   -9999
#    54 -64.05  36.59   1 -9999 73.7646975185   -9999
#    37 -59.12  61.92   1 -9999 85.6111020838   -9999
# ERROR:astropy:TypeError: __init__() got an unexpected keyword argument 'format'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-a2ceadef14f9> in <module>()
#      49 #fibers now includes a radius-group designation for each fiber, so we can radially bin data. This method should actually be fairly extensible to other IFUs
#      50 #we also have a dictionary r_group_dict, which associates each group number with a mean radius
# ---> 51 ascii.write(fibers, 'values.csv', format='csv')
#
# /usr/local/lib64/python2.7/site-packages/astropy-0.2.3-py2.7-linux-x86_64.egg/astropy/io/ascii/ui.pyc in write(table, output, Writer, **kwargs)
#     275     table.cols = table.columns.values()
#     276
# --> 277     writer = get_writer(Writer=Writer, **kwargs)
#     278     lines = writer.write(table)
#     279
#
# /usr/local/lib64/python2.7/site-packages/astropy-0.2.3-py2.7-linux-x86_64.egg/astropy/io/ascii/ui.pyc in get_writer(Writer, **kwargs)
#     242     if 'strip_whitespace' not in kwargs:
#     243         kwargs['strip_whitespace'] = True
# --> 244     writer = core._get_writer(Writer, **kwargs)
#     245     return writer
#     246
#
# /usr/local/lib64/python2.7/site-packages/astropy-0.2.3-py2.7-linux-x86_64.egg/astropy/io/ascii/core.pyc in _get_writer(Writer, **kwargs)
#    1012
#    1013     writer_kwargs = dict([k, v] for k, v in kwargs.items() if k not in extra_writer_pars)
# -> 1014     writer = Writer(**writer_kwargs)
#    1015
#    1016     if 'delimiter' in kwargs:
#
# TypeError: __init__() got an unexpected keyword argument 'format'
# ERROR: TypeError: __init__() got an unexpected keyword argument 'format' [astropy.io.ascii.core]

# %% [markdown]
# # Now correct between SDSS and SparsePak F_lambda

# %%
im, fiberflat = SPaCT.load_ifus_precorrection(objname)

plate = 1927
mjd = 53321
fiber = 290
sdss = fetch_sdss_spectrum(plate, mjd, fiber)

dz, ifu_corr, corr_poly = SPaCT.sdss_cal(im, fiberflat, sdss, dz = 0., z = z, verbose = True, blur = 75, full_output = True)
SPaCT.write_corr_frame(ifu_corr, im, z, dz, objname, verbose = False)

plt.figure(figsize = (6, 4))

response = 1./corr_poly
response /= np.max(response)/.73
plt.plot(response)
plt.ylabel('$\eta_{tot}$')
plt.title('derived 600@10.1 response function')
plt.show()
# Out:
# Un-corrected science frame
# NAXIS1: 1934
# CRVAL1: 3907
# CDELT1: 1.4
# WARNING
# WARNING:astropy:RankWarning: Polyfit may be poorly conditioned
# : RankWarning: Polyfit may be poorly conditioned [numpy.lib.polynomial]
# Median log-error: -2.09234888771

# %%
sci_frame = fits.open(objname + '_fluxcal.fits')[0].data[:,:-100]

fig = plt.figure(figsize = (20,16))

sci_frame_im = plt.imshow((sci_frame.T/np.max(sci_frame, axis = 1)).T, cmap = 'gray', aspect = NAXIS1/75./4., interpolation = 'nearest', origin = 'lower')
plt.colorbar(sci_frame_im, shrink = 0.9)
plt.axvline(1190., linewidth = 1, linestyle = '--', c = 'g')
plt.title ('Fibers', size = 16)
plt.xlim([1100., 1300.])
plt.show()

#=====

sci_frame_g = fits.open(objname + '_fluxcal.fits')[0].data[:,:-100]

fig = plt.figure(figsize = (20,16))

sci_frame_im_g = plt.imshow((sci_frame_g.T/np.max(sci_frame_g, axis = 1)).T, cmap = 'gray', aspect = NAXIS1/75./4., interpolation = 'nearest', origin = 'lower')
plt.colorbar(sci_frame_im_g, shrink = 0.9)
plt.axvline(1190., linewidth = 1, linestyle = '--', c = 'g')
plt.title ('Fibers 1st Deriv.', size = 16)
plt.xlim([1100., 1300.])
plt.show()

# %%
sci_frame = fits.open(objname + '_fluxcal.fits')[0].data[:,:-100]

fig = plt.figure(figsize = (20,16))

sci_frame_im = plt.imshow((sci_frame.T/np.max(sci_frame, axis = 1)).T, cmap = 'gray', aspect = NAXIS1/75./30., interpolation = 'nearest', origin = 'lower')
plt.colorbar(sci_frame_im, shrink = 0.9)
plt.axvline(1190., linewidth = 1, linestyle = '--', c = 'g')
plt.title ('Fibers', size = 16)
plt.xlim([1186., 1195.])
plt.show()

p_cygni_dir = []

for row in sci_frame[:, 1186:1195]:
    p_cygni_dir.append(np.polyfit(np.arange(0., len(row)), row, 1)[0])
    
#=====
#now overlay down-up/up-down designator on image of galaxy
    
fig= plt.figure(figsize=(6,6), dpi=400)

im=mpimg.imread(objname + '.png')
x = y = np.linspace(-40., 40., shape(im)[0])
X, Y = np.meshgrid(x, y)
galim = plt.imshow(im, extent = [-40, 40, -40, 40], origin = 'lower', interpolation = 'nearest', zorder = 0)

fibers.sort(['row'])

#plt.contour(X, Y, im.sum(axis = -1), zorder = 1, cmap = 'Greens')

cir = circles(fibers['ra'][fibers['sky'] != 1], fibers['dec'][fibers['sky'] != 1], s = fibersize/2, c = np.sign(p_cygni_dir), cmap = 'gray', edgecolor = 'w', alpha = 0.8, zorder = 2)
#for row in fibers:
#    if row['sky']!=1:
#        plt.text(row['ra']-1., row['dec']-1.75, s=str(row['fiber']) + '\n' + str(row['row']), color = 'g', size = 14, zorder = 3)
cbar = fig.colorbar(cir, shrink=0.8)
cbar.set_label('P Cygni slope', size = 16)

plt.xlim([-40, 40])
plt.ylim([-40, 40])
plt.xlabel('RA offset (arcsec)', fontsize = 16)
plt.ylabel('Dec offset (arcsec)', fontsize = 16)
plt.title(objname, fontsize=18)
plt.show()

#=====
#now plot fiber data row against up-down/down-up designator
plt.figure(figsize = (6,4))
plt.scatter(np.arange(0., len(p_cygni_dir)), np.sign(p_cygni_dir), marker = '.', c = 'k')

# %% [markdown]
# # Test Spectra

# %%
fig = plt.figure(figsize = (14,10), dpi=200)
ax = fig.add_subplot(111)

im=fits.open(objname + '_fluxcal.fits')
ifu=im[0].data
wavelength = np.linspace(CRVAL1, CRVAL1 + CDELT1 * NAXIS1, NAXIS1, endpoint = True )

fiberlist = [42, 22, 41, 27, 60, 38, 56, 39, 36, 0, 21, 43, 46, 40]
#fiberlist = [47, 42, 22, 41, 27, 60, 38, 39, 36, 0, 21, 43, 46, 40, 56, 37, 18, 19, 24, 20, 29, 72, 64, 58, 74, 57, 50]
fiberlist = [47, 42, 22, 41, 27, 60, 38]

labely = np.linspace(.1, .9, len(fiberlist))

maxes = [ifu[i].max() for i in fiberlist]
maxarray = np.array(zip(fiberlist, maxes))
maxarray = maxarray[maxarray[:,1].argsort()]

for i in fiberlist:
    spectrum, = ax.plot(wavelength[:-90], ifu[i,:-90])
    ax.annotate(str(i), (wavelength[np.argmax(ifu[i])], ifu[i][np.argmax(ifu[i])]), xytext=(.92, labely[np.where(maxarray[:,0]==i)] ), textcoords = 'figure fraction', fontsize = 12, arrowprops=dict(facecolor = 'black', arrowstyle='-|>'), color = spectrum.get_color())

#ax.set_xlim(ax.get_xlim()[0], ax.get_xlim()[1] + 100)

#ax.grid(linestyle = '--')

ax.set_xlabel('observed wavelength ($\AA$)', size = 14)
ax.set_ylabel('$F_{\lambda} [erg/s/cm^{-2}/\AA]$', size = 14)
plt.show()

# %%
#try radial binning
#first plot total flux against by radius
fig = plt.figure(figsize = (6, 4))
total_light = np.sum(ifu, axis=1)
fibers.sort(['row'])

for row in fibers:
    if row['sky']!=1:
        plt.errorbar(r_group_dict[row['r group']], total_light[row['row']], marker = 'x', c = 'k')
plt.xlabel('r (arcsec)')
plt.ylabel('$F_{\lambda}[erg/s/cm^{-2}]$', size = 14)
plt.title('light gathered by radius')
plt.show()

# %%
#try mapping the log of total light onto an IFU fiber diagram
import matplotlib
fig= plt.figure(figsize=(12,12), dpi=400)

#you can get custom-sized images at http://skyserver.sdss3.org/dr10/en/tools/chart/image.aspx
#explore at http://skyserver.sdss3.org/dr10/en/tools/explore/default.aspx

im=mpimg.imread(objname + '.png')
x = y = np.linspace(-40., 40., shape(im)[0])
X, Y = np.meshgrid(x, y)
galim = plt.imshow(im, extent = [-40, 40, -40, 40], origin = 'lower', interpolation = 'nearest', zorder = 0)

total_light = np.sum(ifu, axis=1)
fibers.sort(['row'])

plt.contour(X, Y, im.sum(axis = -1), zorder = 1, cmap = 'Greens')

#print fibers

cir = circles(fibers['ra'][fibers['sky'] != 1], fibers['dec'][fibers['sky'] != 1], s = fibersize/2, c = total_light, edgecolor = 'w', alpha = 0.8, norm=matplotlib.colors.LogNorm(), cmap = 'hot', zorder = 2)
for row in fibers:
    if row['sky']!=1:
        plt.text(row['ra']-1., row['dec']-1.5, s=str(row['fiber']) + '\n' + str(row['row']), color = 'g', size = 14, zorder = 3)
fig.colorbar(cir, shrink=0.8)

plt.xlim([-40, 40])
plt.ylim([-40, 40])
plt.xlabel('RA offset (arcsec)', fontsize = 16)
plt.ylabel('Dec offset (arcsec)', fontsize = 16)
plt.title(objname, fontsize=18)

#this is the correct way to do this!

# %% [markdown]
# # Now trying some PPXF (one fiber)

# %%
from ppxf import ppxf
import ppxf_util as util
import glob
from scipy import ndimage
from time import clock

directory = 'spectra/'

# %%
#first log-rebin the SparsePak spectrum

lamRange1 = np.array([CRVAL1, CRVAL1 + CDELT1 * NAXIS1])
FWHM_gal = 4.877 # FWHM from SparsePak simulator

#need to de-redshift spectrum in order to use pPXF
lamRange1 = lamRange1 / (1 + z)
FWHM_gal = FWHM_gal / (1 + z)

fiber = 27
galaxy, logLam1, velscale = util.log_rebin(lamRange1, ifu[fiber])

#keep track of which pixels are negative, to mask them out later
negative_pixels = np.where(galaxy < 0.)[0]
galaxy = np.abs(galaxy)

print len(ifu[fiber])
# Out:
# 1934

# %%
print velscale[0], 'km/s/pix'

# Read the list of filenames from the Single Stellar Population library
# by Vazdekis (1999, ApJ, 513, 224). A subset of the library is included
# for this example with permission. See http://purl.org/cappellari/idl
# for suggestions of more up-to-date stellar libraries.

template_files = glob.glob(directory + 'Rbi1.30z*.fits')
template_files = glob.glob('miles_models/Mun*.fits')
template_files = [ i for i in template_files if float(i[-12:-5]) < 13.6 ]
FWHM_tem = 1.8 # Vazdekis spectra have a resolution FWHM of 1.8A.
FWHM_tem = 1.5 # Miles spectra have FWHM of 1.5A

# Extract the wavelength range and logarithmically rebin one spectrum
# to the same velocity scale of the SparsePak galaxy spectrum, to determine
# the size needed for the array which will contain the template spectra.

hdu = fits.open(template_files[0])
ssp = hdu[0].data
h2 = hdu[0].header
lamRange2 = h2['CRVAL1'] + np.array([0.,h2['CDELT1']*(h2['NAXIS1']-1)])
sspNew, logLam2, velscale = util.log_rebin(lamRange2, ssp, velscale=velscale)
templates = np.empty((sspNew.size,len(template_files)))

print 'SparsePak range:', lamRange1
print 'Template range:', lamRange2

# Pare down the SparsePak spectrum so that its wavelength range is
# contained within the template spectrum's wavelength range

galaxy = galaxy[(logLam1 >= logLam2[0]) * (logLam1 <= logLam2[-1])]
logLam1 = logLam1[(logLam1 >= logLam2[0]) * (logLam1 <= logLam2[-1])]
# the MILES templates run into issues at the red end of the spectra b/c of correction in interpolation
if 'miles' in template_files[0]: galaxy, logLam1 = galaxy, logLam1
if directory in template_files[0]: galaxy, logLam1 = galaxy[:10], logLam1[:-10]

l = np.exp(logLam1)
# Out:
# 81.6592897072 km/s/pix
# SparsePak range: [ 3843.17410179  6506.54195385]
# Template range: [ 3540.5  7409.6]

# %%
plt.figure(figsize = (6,4))

for i in 2.*np.arange(1, 60) + 1:
    i = int(i)
    #print i
    noise_temp = SPaCT.noise_edgefibers(ifu, i)
    plt.plot(i, np.mean(galaxy / noise_temp), c = 'b', marker = '.')
    
plt.show()

# %%
#now use the edge fibers to compute the average noise at each wavelength

noise = SPaCT.noise_edgefibers(ifu, 25)
print 'Avg SNR =', np.mean(galaxy/noise)

plt.figure(figsize = (8, 6))
plt.hist(noise, bins = 50)
plt.axvline(np.median(noise), c = 'r', linestyle = '--')
plt.title('Noise')
plt.legend(loc = 'best')
plt.show()

plt.figure(figsize = (6, 4))
plt.hist(galaxy/noise, bins = 50)
plt.axvline(np.mean(galaxy/noise), c = 'r', linestyle = '--')
plt.title('$S/N$')
plt.show()

plt.figure(figsize = (8, 6))
plt.plot(galaxy/noise)
plt.show()
# Out:
# Avg SNR = 291.101399329

# %%
#try comparing the SNR with scipy.signaltonoise
edgefibers = [51, 4, 1, 8, 10, 65, 71, 53, 31, 63, 32, 14 ]

plt.figure(figsize = (8, 6))
plt.hist(np.mean(ifu[edgefibers], axis = 0) / signaltonoise(ifu[edgefibers]), bins = 50)
#plt.axvline(np.median(signaltonoise(ifu[edgefibers])), c = 'r', linestyle = '--')
plt.title('Noise')
plt.legend(loc = 'best')
plt.show()

plt.figure(figsize = (8, 6))
plt.plot(ifu[fiber] / (np.mean(ifu[edgefibers], axis = 0) / signaltonoise(ifu[edgefibers])))
#plt.axvline(np.median(signaltonoise(ifu[edgefibers])), c = 'r', linestyle = '--')
plt.title('SNR')
plt.legend(loc = 'best')
plt.show()

plt.figure(figsize = (8, 6))
plt.hist(ifu[fiber] / (np.mean(ifu[edgefibers], axis = 0) / signaltonoise(ifu[edgefibers])), bins = 50)
#plt.axvline(np.median(signaltonoise(ifu[edgefibers])), c = 'r', linestyle = '--')
plt.title('SNR')
plt.legend(loc = 'best')
plt.show()

print np.mean(ifu[fiber] / (np.mean(ifu[edgefibers], axis = 0) / signaltonoise(ifu[edgefibers])))

noise_2 = np.mean(ifu[edgefibers], axis = 0) / signaltonoise(ifu[edgefibers])
# Out:
# 69.0157154279

# %%
#munge the templates to get characteristics
ssp_rows = []
from astropy.table import Table
import astropy

for template in template_files:
    template = template.rstrip('.fits').split('/')[1]
    
    spectral_range = template[0]
    IMF_type = template[1:3]
    IMF_slope = float(template[3:7])
    Z = plusminus(template[8])*float(template[9:13])
    T = float(template[14:])
    
    #print template + ':', spectral_range, IMF_type, IMF_slope, Z, T
    ssp_i = [template, spectral_range, IMF_type, IMF_slope, Z, T]
    ssp_rows.append(ssp_i)
    

ssps = Table(map(list, zip(*ssp_rows)), names = ['template name', 'spectral range', 'IMF type', 'IMF slope', 'Z', 't'])
print ssps
plt.figure(figsize = (4,6))
plt.scatter(ssps['Z'], ssps['t'])
# Out:
#     template name     spectral range IMF type IMF slope   Z     t
# --------------------- -------------- -------- --------- ----- ------
# Mun1.30Zm0.71T02.2387              M       un       1.3 -0.71 2.2387
# Mun1.30Zm0.71T02.5119              M       un       1.3 -0.71 2.5119
# Mun1.30Zm0.71T02.8184              M       un       1.3 -0.71 2.8184
# Mun1.30Zm0.71T03.1623              M       un       1.3 -0.71 3.1623
# Mun1.30Zm0.71T03.5481              M       un       1.3 -0.71 3.5481
# Mun1.30Zm0.71T03.9811              M       un       1.3 -0.71 3.9811
# Mun1.30Zm0.71T04.4668              M       un       1.3 -0.71 4.4668
# Mun1.30Zm0.71T05.0119              M       un       1.3 -0.71 5.0119
# Mun1.30Zm0.71T05.6234              M       un       1.3 -0.71 5.6234
# Mun1.30Zm0.71T06.3096              M       un       1.3 -0.71 6.3096
# Mun1.30Zm0.71T07.0795              M       un       1.3 -0.71 7.0795
#                   ...            ...      ...       ...   ...    ...
# Mun1.30Zp0.00T01.0000              M       un       1.3   0.0    1.0
# Mun1.30Zp0.00T01.7783              M       un       1.3   0.0 1.7783
# Mun1.30Zp0.00T07.9433              M       un       1.3   0.0 7.9433
# Mun1.30Zp0.00T02.8184              M       un       1.3   0.0 2.8184
# Mun1.30Zp0.00T01.9953              M       un       1.3   0.0 1.9953
# Mun1.30Zp0.00T04.4668              M       un       1.3   0.0 4.4668
# Mun1.30Zp0.00T03.1623              M       un       1.3   0.0 3.1623
# Mun1.30Zp0.00T03.9811              M       un       1.3   0.0 3.9811
# Mun1.30Zp0.00T06.3096              M       un       1.3   0.0 6.3096
# Mun1.30Zp0.00T08.9125              M       un       1.3   0.0 8.9125
# Mun1.30Zp0.22T05.0119              M       un       1.3  0.22 5.0119

# %%
# Convolve the whole SSP library of spectral templates
# with the quadratic difference between the SAURON and the
# Vazdekis instrumental resolution. Logarithmically rebin
# and store each template as a column in the array TEMPLATES.

# Quadratic sigma difference in pixels SSP --> instrument FWHM
# The formula below is rigorously valid if the shapes of the
# instrumental spectral profiles are well approximated by Gaussians.

FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
sigma = FWHM_dif/2.355/h2['CDELT1'] # Sigma difference in pixels

for j in range(len(template_files)):
    hdu = fits.open(template_files[j])
    ssp = hdu[0].data
    ssp = ndimage.gaussian_filter1d(ssp,sigma)
    sspNew, logLam2, velscale = util.log_rebin(lamRange2, ssp, velscale=velscale)
    templates[:,j] = sspNew/np.median(sspNew) # Normalizes templates

# %%
# The galaxy and the template spectra do not have the same starting wavelength.
# For this reason an extra velocity shift DV has to be applied to the template
# to fit the galaxy spectrum. We remove this artificial shift by using the
# keyword VSYST in the call to PPXF below, so that all velocities are
# measured with respect to DV. This assume the redshift is negligible.
# In the case of a high-redshift galaxy one should de-redshift its
# wavelength to the rest frame before using the line below (see above).

c = 299792.458
dv = (logLam2[0]-logLam1[0])*c # km/s
print 'dv:', dv, 'km/s'

vel = 0.
print 'SDSS velocity:', c*z, 'km/s'
goodPixels = util.determine_goodpixels(logLam1,lamRange2,vel)
#mask out the OI sky line and whatever weirdness goes along with it
goodPixels = np.array([pixel for pixel in goodPixels if not 1183 <= pixel <= 1200])
#mask out last 100 pixels with weird end behavior
goodPixels = np.array([pixel for pixel in goodPixels if not len(galaxy) - 100 <= pixel <= len(galaxy)])
#mask out pixels that were originally negative
goodPixels = np.array([pixel for pixel in goodPixels if pixel not in negative_pixels])
# Out:
# dv: -24576.5325627 km/s
# SDSS velocity: 4978.83322548 km/s

# %%
# Here the actual fit starts. The best fit is plotted on the screen.
# Gas emission lines are excluded from the pPXF fit using the GOODPIXELS keyword.

start = [vel, 3.*velscale] # (km/s), starting guess for [V,sigma]
t = clock()

plt.subplot(211)

pp = ppxf(templates, galaxy/np.median(galaxy), noise_2/np.median(galaxy), velscale, start, 
          goodpixels = goodPixels, clean = True, plot = True, moments = 4, degree = 4, 
          vsyst = dv, bias = 0., reddening = .0485, lam = np.exp(logLam1))
plt.fill_between(np.arange(0, len(noise_2)), galaxy - noise_2, galaxy + noise_2, edgecolor = 'green', facecolor = 'green', alpha = 0.5)

plt.tick_params(axis='both', which='major', labelsize=16)

plt.twiny()
newxticks = np.linspace(-.02, 1.02, 10)
newxticklabels = CRVAL1 + newxticks*NAXIS1*CDELT1
plt.xticks(newxticks, newxticklabels.astype(int))
plt.xlabel('$\lambda[\AA]$', size = 16)


#look for emission lines
balmer = [ ['$\\alpha$', 6563.], ['$\\beta$', 4861.], ['$\\gamma$', 4341.], ['$\\delta$', 4102.] ]
for line in balmer:
    line_c = cmodels.irgb_string_from_xyz(ciexyz.xyz_from_wavelength(line[1]/10.))
    plt.axvline(line[1] * ((z + 1)*(1 + pp.sol[0]/c)), color = line_c)
    plt.annotate('H-' + line[0], xy = (line[1], 1.2), xytext = (line[1]+10., 1.2), size = 14)

plt.tick_params(axis='both', which='major', labelsize=16)

plt.subplot(212)
s = templates.shape
print s
print np.size(pp.weights)
weights = pp.weights.reshape(23, 6)/pp.weights.sum()
plt.imshow(np.rot90(weights), interpolation='nearest', cmap='gnuplot2_r',
           aspect='auto', extent=(np.log10(np.min(ssps['t'])), np.log10(np.max(ssps['t'])), np.min(ssps['Z']), np.max(ssps['Z'])))
plt.colorbar()
plt.title("Mass Fraction", size = 16)
plt.xlabel("log$_{10}$ Age (Gyr)", size = 16)
plt.ylabel("[M/H]", size = 16)
plt.tick_params(axis='both', which='major', labelsize=16)

print("Formal errors:")
print("     dV    dsigma   dh3      dh4")
print("".join("%8.2g" % f for f in pp.error*np.sqrt(pp.chi2)))

print('Elapsed time in PPXF: %.2f s' % (clock() - t))
print 'Best-fitting redshift z:', (z + 1)*(1 + pp.sol[0]/c) - 1, '+/-', np.abs((pp.error*np.sqrt(pp.chi2)/c))[0]

plt.show()
# Out:
# Outliers: 257
# Outliers: 16
# Outliers: 9
# Outliers: 4
# Outliers: 2
# Outliers: 2
# Outliers:
#  256
# Outliers: 17
# Outliers: 3
# Outliers: 4
# Outliers: 2
# Outliers: 1
# Outliers:
#  4
# Outliers: 2
# Outliers: 1
# Outliers:
#  255
# Outliers: 17
# Outliers: 4
# Outliers: 3
# Outliers: 2
# Outliers: 2
# Outliers:
#  3
# Outliers: 3
# Outliers:
#  254
# Outliers: 17
# Outliers: 4
# Outliers: 4
# Outliers: 4
# Outliers: 1
# Outliers:
#  254
# Outliers: 17
# Outliers: 5
# Outliers: 3
# Outliers: 2
# Outliers: 2
# Outliers:
#  1
# Outliers: 1
# Outliers: 2
# Best Fit:       V     sigma        h3        h4        h5        h6
# comp. 0       43.6       198    0.0337    0.0151
# chi2/DOF: 1.776
# Function evaluations: 20
# Reddening E(B-V):  0.360619791364
# Nonzero Templates:  3  /  138
# (2711, 138)
# 138
# Formal errors:
#      dV    dsigma   dh3      dh4
#       58 2.6e+02   0.045    0.02
# Elapsed time in PPXF: 3.57 s
# Best-fitting redshift z: 0.0167555167304 +/- 0.000193910251643

# %%
plt.figure(figsize = (8,6))

noise_scales = np.concatenate((np.logspace(-1, 1, 25), np.linspace(10, 100, 25)))
for i in noise_scales:
    start = [vel, 3.*velscale] # (km/s), starting guess for [V,sigma]
    t = clock()
    
    pp = ppxf(templates, galaxy/np.median(galaxy), i*noise_2/np.median(galaxy), velscale, start, goodpixels = goodPixels, clean = True, plot = False, moments = 4, degree = 4, vsyst = dv, quiet = True, bias = 0., reddening = .0485, lam = np.exp(logLam1))
    #plt.fill_between(np.arange(0, len(noise)), galaxy - noise, galaxy + noise, edgecolor = 'green', facecolor = 'green', alpha = 0.5)
    #plt.show()
    #print("Formal errors:")
    #print("     dV    dsigma   dh3      dh4")
    #print("".join("%8.2g" % f for f in pp.error*np.sqrt(pp.chi2)))
    
    #print('Elapsed time in PPXF: %.2f s' % (clock() - t))
    #print 'Best-fitting redshift z:', (z + 1)*(1 + pp.sol[0]/c) - 1, '+/-', np.abs((pp.error*np.sqrt(pp.chi2)/c))[0]
    #print i, pp.chi2
    plt.semilogx(i, pp.chi2, c = 'b', marker = '.')

plt.axhline(1.5, c = 'r', linestyle = '--')
plt.axvline(1.0, c = 'r', linestyle = '--')
plt.xlabel('Noise multiplication factor', size = 16)
plt.ylabel('$\chi/DOF$', size = 16)
plt.show()

# %%
#populations present
populations = [list(a) for a in zip([i.rstrip('.fits').lstrip('miles_models/') for i in template_files], pp.weights/np.sum(pp.weights)) if a[1] != 0.]
populations = Table(np.array(populations), names = ['template name', 'fraction'])

populations.add_column(astropy.table.Column(name='Z', data=[ plusminus(i[8])*float(i[9:13]) for i in populations['template name'] ] ))
populations.add_column(astropy.table.Column(name='IMF slope', data=[ float(i[3:7]) for i in populations['template name'] ] ))
populations.add_column(astropy.table.Column(name='age', data=[ float(i[-7:]) for i in populations['template name'] ] ))
populations.add_column(astropy.table.Column(name='range', data=[ i[0] for i in populations['template name'] ] ))
populations.add_column(astropy.table.Column(name='IMF type', data=[ i[1:3] for i in populations['template name'] ] ))
populations
# Out:
# <Table rows=3 names=('template name','fraction','Z','IMF slope','age','range','IMF type')>
# array([ ('Mun1.30Zm0.40T12.5893', '0.465124105524', -0.4, 1.3, 12.5893, 'M', 'un'),
#        ('Mun1.30Zm0.71T01.0000', '0.0421245404041', -0.71, 1.3, 1.0, 'M', 'un'),
#        ('Mun1.30Zp0.22T11.2202', '0.492751354072', 0.22, 1.3, 11.2202, 'M', 'un')],
#       dtype=[('template name', 'S21'), ('fraction', 'S21'), ('Z', '<f8'), ('IMF slope', '<f8'), ('age', '<f8'), ('range', 'S1'), ('IMF type', 'S2')])

# %%
SPaCT.SP_pPXF(ifu, 47, (CRVAL1, CDELT1, NAXIS1), z, verbose = True, noise_plots = True, fit_plots = True, reddening = .0495)
# Out:
# 81.6592897072 km/s/pix
# SparsePak range:
#  [ 3843.17410179  6506.54195385]
# Template range: [ 3540.5  7409.6]
#     template name     spectral range IMF type IMF slope   Z     t
# --------------------- -------------- -------- --------- ----- ------
# Mun1.30Zm0.71T02.2387              M       un       1.3 -0.71 2.2387
# Mun1.30Zm0.71T02.5119              M       un       1.3 -0.71 2.5119
# Mun1.30Zm0.71T02.8184              M       un       1.3 -0.71 2.8184
# Mun1.30Zm0.71T03.1623              M       un       1.3 -0.71 3.1623
# Mun1.30Zm0.71T03.5481              M       un       1.3 -0.71 3.5481
# Mun1.30Zm0.71T03.9811              M       un       1.3 -0.71 3.9811
# Mun1.30Zm0.71T04.4668              M       un       1.3 -0.71 4.4668
# Mun1.30Zm0.71T05.0119              M       un       1.3 -0.71 5.0119
# Mun1.30Zm0.71T05.6234              M       un       1.3 -0.71 5.6234
# Mun1.30Zm0.71T06.3096              M       un       1.3 -0.71 6.3096
# Mun1.30Zm0.71T07.0795              M       un       1.3 -0.71 7.0795
#                   ...            ...      ...       ...   ...    ...
# Mun1.30Zp0.00T01.0000              M       un       1.3   0.0    1.0
# Mun1.30Zp0.00T01.7783              M       un       1.3   0.0 1.7783
# Mun1.30Zp0.00T07.9433              M       un       1.3   0.0 7.9433
# Mun1.30Zp0.00T02.8184              M       un       1.3   0.0 2.8184
# Mun1.30Zp0.00T01.9953              M       un       1.3   0.0 1.9953
# Mun1.30Zp0.00T04.4668              M       un       1.3   0.0 4.4668
# Mun1.30Zp0.00T03.1623              M       un       1.3   0.0 3.1623
# Mun1.30Zp0.00T03.9811              M       un       1.3   0.0 3.9811
# Mun1.30Zp0.00T06.3096              M       un       1.3   0.0 6.3096
# Mun1.30Zp0.00T08.9125              M       un       1.3   0.0 8.9125
# Mun1.30Zp0.22T05.0119              M       un       1.3  0.22 5.0119
# dv: -24576.5325627 km/s
# SDSS velocity: 4978.83322548 km/s
# Outliers:
#  964
# Outliers: 18
# Outliers: 8
# Outliers: 1
# Outliers: 3
# Outliers: 1
# Outliers: 2
# Outliers:
#  964
# Outliers: 18
# Outliers: 9
# Outliers: 2
# Outliers: 1
# Outliers:
#  963
# Outliers: 21
# Outliers: 6
# Outliers: 1
# Outliers: 1
# Outliers:
#  967
# Outliers: 15
# Outliers: 5
# Outliers: 4
# Outliers: 2
# Outliers: 2
# Outliers:
#  968
# Outliers: 17
# Outliers: 3
# Outliers: 2
# Best Fit:       V     sigma        h3        h4        h5        h6
# comp. 0        -47       214    0.0995     0.124
# chi2/DOF: 2.309
# Function evaluations: 32
# Reddening E(B-V):  0.209334065456
# Nonzero Templates:  5  /  138
# (2711, 138)
# 138
# Formal errors:
#      dV    dsigma   dh3      dh4
#      -71 3.3e+02    0.15    0.19
# Elapsed time in PPXF: 3.82 s
# Best-fitting redshift z: 0.0164480603791 +/- 0.000238466855752

# %% [markdown]
# # pPXF in all fibers

# %%
fiberlist = fibers['row'][fibers['row'] != -9999]

# %%
Z_list = []
sigma_list = []
age_list = []

for fiber in fiberlist:
    print 'Fitting fiber', fiber
    #first log-rebin the SparsePak spectrum

    lamRange1 = np.array([CRVAL1, CRVAL1 + CDELT1 * NAXIS1])
    FWHM_gal = 4.877 # FWHM from SparsePak simulator
    
    #need to de-redshift spectrum in order to use pPXF
    lamRange1 = lamRange1 / (1 + z)
    FWHM_gal = FWHM_gal / (1 + z)
    
    galaxy, logLam1, velscale = util.log_rebin(lamRange1, ifu[fiber])
    galaxy = np.abs(galaxy)
    galaxy = galaxy/np.median(galaxy)
    
    ##print velscale[0], 'km/s/pix'
    
    # Read the list of filenames from the Single Stellar Population library
    # by Vazdekis (1999, ApJ, 513, 224). A subset of the library is included
    # for this example with permission. See http://purl.org/cappellari/idl
    # for suggestions of more up-to-date stellar libraries.
    
    template_files = glob.glob(directory + 'Rbi1.30z*.fits')
    template_files = glob.glob('miles_models/Mun*.fits')
    template_files = [ i for i in template_files if float(i[-12:-5]) < 13.6 ]
    FWHM_tem = 1.8 # Vazdekis spectra have a resolution FWHM of 1.8A.
    FWHM_tem = 1.5 # Miles spectra have FWHM of 1.5A
    
    # Extract the wavelength range and logarithmically rebin one spectrum
    # to the same velocity scale of the SparsePak galaxy spectrum, to determine
    # the size needed for the array which will contain the template spectra.
    
    hdu = fits.open(template_files[0])
    ssp = hdu[0].data
    h2 = hdu[0].header
    lamRange2 = h2['CRVAL1'] + np.array([0.,h2['CDELT1']*(h2['NAXIS1']-1)])
    sspNew, logLam2, velscale = util.log_rebin(lamRange2, ssp, velscale=velscale)
    templates = np.empty((sspNew.size,len(template_files)))
    
    ##print 'SparsePak range:', lamRange1
    ##print 'Template range:', lamRange2
    
    # Pare down the SparsePak spectrum so that its wavelength range is
    # contained within the template spectrum's wavelength range
    
    galaxy = galaxy[(logLam1 >= logLam2[0]) * (logLam1 <= logLam2[-1])]
    logLam1 = logLam1[(logLam1 >= logLam2[0]) * (logLam1 <= logLam2[-1])]
    # the MILES templates run into issues at the red end of the spectra b/c of correction in interpolation
    if 'miles' in template_files[0]: galaxy, logLam1 = galaxy[200:-200], logLam1[200:-200]
    if directory in template_files[0]: galaxy, logLam1 = galaxy[:10], logLam1[:-10]
    
    noise = SPaCT.counts_to_flux(np.sqrt(SPaCT.flux_to_counts(galaxy, np.exp(logLam1))), np.exp(logLam1))
    '''
    plt.figure(figsize = (6, 4))
    plt.hist(noise, bins = 50, label = 'Poisson')
    plt.title('Noise')
    plt.xlabel('$F_\lambda [10^{-17} erg/s/cm^2/A]$')
    plt.legend(loc = 'best')
    plt.show()
    '''
    #print len(galaxy), len(sspNew)
    '''
    plt.figure(figsize = (6, 4))
    plt.hist(galaxy/noise, bins = 50, label = 'Poisson')
    plt.title('SNR')
    plt.legend(loc = 'best')
    plt.show()
    '''
    # Convolve the whole SSP library of spectral templates
    # with the quadratic difference between the SAURON and the
    # Vazdekis instrumental resolution. Logarithmically rebin
    # and store each template as a column in the array TEMPLATES.
    
    # Quadratic sigma difference in pixels SSP --> instrument FWHM
    # The formula below is rigorously valid if the shapes of the
    # instrumental spectral profiles are well approximated by Gaussians.
    
    FWHM_dif = np.sqrt(FWHM_gal**2 - FWHM_tem**2)
    sigma = FWHM_dif/2.355/h2['CDELT1'] # Sigma difference in pixels
    
    for j in range(len(template_files)):
        hdu = fits.open(template_files[j])
        ssp = hdu[0].data
        ssp = ndimage.gaussian_filter1d(ssp,sigma)
        sspNew, logLam2, velscale = util.log_rebin(lamRange2, ssp, velscale=velscale)
        templates[:,j] = sspNew/np.median(sspNew) # Normalizes templates
    
    # The galaxy and the template spectra do not have the same starting wavelength.
    # For this reason an extra velocity shift DV has to be applied to the template
    # to fit the galaxy spectrum. We remove this artificial shift by using the
    # keyword VSYST in the call to PPXF below, so that all velocities are
    # measured with respect to DV. This assume the redshift is negligible.
    # In the case of a high-redshift galaxy one should de-redshift its
    # wavelength to the rest frame before using the line below (see above).
    
    c = 299792.458
    dv = (logLam2[0]-logLam1[0])*c # km/s
    ##print 'dv:', dv, 'km/s'
    
    vel = 0.
    ##print 'SDSS velocity:', c*z, 'km/s'
    goodPixels = util.determine_goodpixels(logLam1,lamRange2,vel)
    
    if fiber == 37:
        goodPixels = np.array([pixel for pixel in goodPixels if 1185 <= pixel <= 1198])
    
    # Here the actual fit starts. The best fit is plotted on the screen.
    # Gas emission lines are excluded from the pPXF fit using the GOODPIXELS keyword.
    
    start = [vel, 3.*velscale] # (km/s), starting guess for [V,sigma]
    t = clock()
    
    pp = ppxf(templates, galaxy, noise, velscale, start, goodpixels = goodPixels, clean = True, plot = False, quiet = True, moments = 4, degree = 4, vsyst = dv, bias = 0., reddening = .0485, lam = np.exp(logLam1))
    ##plt.fill_between(np.arange(0, len(noise)), galaxy - noise, galaxy + noise, edgecolor = 'green', facecolor = 'green', alpha = 0.5)
    ##plt.show()
    ##print("Formal errors:")
    ##print("     dV    dsigma   dh3      dh4")
    ##print("".join("%8.2g" % f for f in pp.error*np.sqrt(pp.chi2)))
    
    ##print('Elapsed time in PPXF: %.2f s' % (clock() - t))
    ##print 'Best-fitting redshift z:', (z + 1)*(1 + pp.sol[0]/c) - 1, '+/-', np.abs((pp.error*np.sqrt(pp.chi2)/c))[0]
    
    #populations present
    populations = [list(a) for a in zip([i.rstrip('.fits').lstrip('miles_models/') for i in template_files], pp.weights/np.sum(pp.weights)) if a[1] != 0.]
    populations = Table(np.array(populations), names = ['template name', 'fraction'])
    
    populations.add_column(astropy.table.Column(name='Z', data=[ plusminus(i[8])*float(i[9:13]) for i in populations['template name'] ] ))
    populations.add_column(astropy.table.Column(name='IMF slope', data=[ float(i[3:7]) for i in populations['template name'] ] ))
    populations.add_column(astropy.table.Column(name='age', data=[ float(i[-7:]) for i in populations['template name'] ] ))
    populations.add_column(astropy.table.Column(name='range', data=[ i[0] for i in populations['template name'] ] ))
    populations.add_column(astropy.table.Column(name='IMF type', data=[ i[1:3] for i in populations['template name'] ] ))
    Z_list.append(np.log(np.average(np.exp(populations['Z']), weights = populations['fraction'])))
    sigma_list.append(pp.sol[1])
    age_list.append(np.average(populations['age'], weights = populations['fraction']))
# Out:
# Fitting fiber 0
# Fitting fiber
#  1
# Fitting fiber
#  2
# Fitting fiber
#  3
# Fitting fiber
#  4
# Fitting fiber
#  5
# Fitting fiber
#  6
# Fitting fiber
#  7
# Fitting fiber
#  8
# Fitting fiber
#  9
# Fitting fiber
#  10
# Fitting fiber
#  11
# Fitting fiber
#  12
# Fitting fiber
#  13
# Fitting fiber
#  14
# WARNING
# WARNING:astropy:RuntimeWarning: invalid value encountered in divide
# : RuntimeWarning: invalid value encountered in divide [unknown]
# Fitting fiber 15
# Fitting fiber
#  16
# Fitting fiber
#  17
# Fitting fiber
#  18
# Fitting fiber
#  19
# Fitting fiber
#  20
# Fitting fiber
#  21
# Fitting fiber
#  22
# Fitting fiber
#  23
# Fitting fiber
#  24
# Fitting fiber
#  25
# Fitting fiber
#  26
# Fitting fiber
#  27
# Fitting fiber
#  28
# Fitting fiber
#  29
# Fitting fiber
#  30
# Fitting fiber
#  31
# Fitting fiber
#  32
# Fitting fiber
#  33
# Fitting fiber
#  34
# Fitting fiber
#  35
# Fitting fiber
#  36
# Fitting fiber
#  37
# Fitting fiber
#  38
# Fitting fiber
#  39
# Fitting fiber
#  40
# Fitting fiber
#  41
# Fitting fiber
#  42
# Fitting fiber
#  43
# Fitting fiber
#  44
# Fitting fiber
#  45
# Fitting fiber
#  46
# Fitting fiber
#  47
# Fitting fiber
#  48
# Fitting fiber
#  49
# Fitting fiber
#  50
# Fitting fiber
#  51
# Fitting fiber
#  52
# Fitting fiber
#  53
# Fitting fiber
#  54
# Fitting fiber
#  55
# Fitting fiber
#  56
# Fitting fiber
#  57
# Fitting fiber
#  58
# Fitting fiber
#  59
# Fitting fiber
#  60
# Fitting fiber
#  61
# Fitting fiber
#  62
# Fitting fiber
#  63
# Fitting fiber
#  64
# Fitting fiber
#  65
# Fitting fiber
#  66
# Fitting fiber
#  67
# Fitting fiber
#  68
# Fitting fiber
#  69
# Fitting fiber
#  70
# Fitting fiber
#  71
# Fitting fiber
#  72
# Fitting fiber
#  73
# Fitting fiber
#  74

# %%
fig= plt.figure(figsize=(6,6), dpi=400)

#you can get custom-sized images at http://skyserver.sdss3.org/dr10/en/tools/chart/image.aspx
#explore at http://skyserver.sdss3.org/dr10/en/tools/explore/default.aspx

im=mpimg.imread(objname + '.png')
x = y = np.linspace(-40., 40., shape(im)[0])
X, Y = np.meshgrid(x, y)
galim = plt.imshow(im, extent = [-40, 40, -40, 40], origin = 'lower', interpolation = 'nearest', zorder = 0)

fibers.sort(['row'])

#plt.contour(X, Y, im.sum(axis = -1), zorder = 1, cmap = 'Greens')

Z_list[37] = 0.

print np.isnan(Z_list)

cir = circles(fibers['ra'][fibers['sky'] != 1], fibers['dec'][fibers['sky'] != 1], s = fibersize/2, c = np.ma.array(Z_list, mask = np.isnan(Z_list)), cmap = 'gnuplot2', edgecolor = 'w', alpha = 0.8, zorder = 2)
#for row in fibers:
#    if row['sky']!=1:
#        plt.text(row['ra']-1., row['dec']-1.75, s=str(row['fiber']) + '\n' + str(row['row']), color = 'g', size = 14, zorder = 3)
cbar = fig.colorbar(cir, shrink=0.8)
cbar.set_label('Metallicity [$M/H$]', size = 16)

plt.xlim([-40, 40])
plt.ylim([-40, 40])
plt.xlabel('RA offset (arcsec)', fontsize = 16)
plt.ylabel('Dec offset (arcsec)', fontsize = 16)
plt.title(objname, fontsize=18)
plt.show()

#this is the correct way to do this!
# Out:
# WARNING:astropy:RuntimeWarning: invalid value encountered in greater
# WARNING:astropy:RuntimeWarning: invalid value encountered in less
# [False False False False False False False False False False False False
#  False False  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False]
# WARNING: RuntimeWarning: invalid value encountered in greater [matplotlib.colorbar]
# WARNING: RuntimeWarning: invalid value encountered in less [matplotlib.colorbar]
# WARNING
# WARNING:astropy:RuntimeWarning: invalid value encountered in less
# : RuntimeWarning: invalid value encountered in less [matplotlib.colors]

# %%
plt.figure(figsize = (8,6))
for row in fibers[fibers['sky'] != 1]:
    plt.plot(row['r'], Z_list[row['row']], marker = 'x', c = 'k')
plt.xlabel('radius (arcsec)', fontsize = 16)
plt.ylabel('metallicity', fontsize = 16)

# %%
fig= plt.figure(figsize=(6,6), dpi=400)

#you can get custom-sized images at http://skyserver.sdss3.org/dr10/en/tools/chart/image.aspx
#explore at http://skyserver.sdss3.org/dr10/en/tools/explore/default.aspx

im=mpimg.imread(objname + '.png')
x = y = np.linspace(-40., 40., shape(im)[0])
X, Y = np.meshgrid(x, y)
galim = plt.imshow(im, extent = [-40, 40, -40, 40], origin = 'lower', interpolation = 'nearest', zorder = 0)

fibers.sort(['row'])

#plt.contour(X, Y, im.sum(axis = -1), zorder = 1, cmap = 'Greens')

cir = circles(fibers['ra'][fibers['sky'] != 1], fibers['dec'][fibers['sky'] != 1], s = fibersize/2, c = np.ma.array(sigma_list, mask = np.isnan(sigma_list)), cmap = 'gnuplot2', edgecolor = 'w', alpha = 0.8, zorder = 2)
#for row in fibers:
#    if row['sky']!=1:
#        plt.text(row['ra']-1., row['dec']-1.75, s=str(row['fiber']) + '\n' + str(row['row']), color = 'g', size = 14, zorder = 3)
cbar = fig.colorbar(cir, shrink=0.8)
cbar.set_label('Velocity dispersion [$km/s$]', size = 16)

plt.xlim([-40, 40])
plt.ylim([-40, 40])
plt.xlabel('RA offset (arcsec)', fontsize = 16)
plt.ylabel('Dec offset (arcsec)', fontsize = 16)
plt.title(objname, fontsize=18)
plt.show()

# %%
plt.figure(figsize = (8,6))
for row in fibers[fibers['sky'] != 1]:
    plt.plot(row['r'], sigma_list[row['row']], marker = 'x', c = 'k')
plt.xlabel('radius (arcsec)', fontsize = 16)
plt.ylabel('$\sigma_v$', fontsize = 16)
plt.axhline(177.9)

# %%
fig= plt.figure(figsize=(6,6), dpi=400)

#you can get custom-sized images at http://skyserver.sdss3.org/dr10/en/tools/chart/image.aspx
#explore at http://skyserver.sdss3.org/dr10/en/tools/explore/default.aspx

im=mpimg.imread(objname + '.png')
x = y = np.linspace(-40., 40., shape(im)[0])
X, Y = np.meshgrid(x, y)
galim = plt.imshow(im, extent = [-40, 40, -40, 40], origin = 'lower', interpolation = 'nearest', zorder = 0)

fibers.sort(['row'])

#plt.contour(X, Y, im.sum(axis = -1), zorder = 1, cmap = 'Greens')

age_list[14] = np.nanmean(age_list)

#print fibers

cir = circles(fibers['ra'][fibers['sky'] != 1], fibers['dec'][fibers['sky'] != 1], s = fibersize/2, c = np.ma.array(age_list, mask = np.isnan(age_list)), cmap = 'gnuplot2', edgecolor = 'w', alpha = 0.8, zorder = 2)
#for row in fibers:
#    if row['sky']!=1:
#        plt.text(row['ra']-1., row['dec']-1.75, s=str(row['fiber']) + '\n' + str(row['row']), color = 'g', size = 14, zorder = 3)
cbar = fig.colorbar(cir, shrink=0.8)
cbar.set_label('Mean SSP age [Gyr]', size = 16)

plt.xlim([-40, 40])
plt.ylim([-40, 40])
plt.xlabel('RA offset (arcsec)', fontsize = 16)
plt.ylabel('Dec offset (arcsec)', fontsize = 16)
plt.title(objname, fontsize=18)
plt.show()

# %%
plt.figure(figsize = (8,6))
for row in fibers[fibers['sky'] != 1]:
    plt.plot(row['r'], age_list[row['row']], marker = 'x', c = 'k')
plt.xlabel('radius (arcsec)', fontsize = 16)
plt.ylabel('age [Gyr]', fontsize = 16)
